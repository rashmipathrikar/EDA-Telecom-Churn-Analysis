# %% [markdown]
# <a href="https://colab.research.google.com/github/rashmipathrikar/EDA-Telecom-Churn-Analysis/blob/main/EDA_Telecom_Churn_Analysis_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Problem Statement**
#
# # Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription. Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention.

# %% [markdown]
# # Importing modules required for exploratory data analysis

# %%
#importing the required packages
import pandas as pd
import numpy as np

#import visualization packages
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Mounting Drive and Loading Dataset

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#Loading dataset required
path ="/content/drive/MyDrive/eda analysis/Copy of Telecom Churn.csv"
telecom= pd.read_csv(path)

# %% [markdown]
# Understanding more about Data available

# %%
# to look the glimps of the data of top 5 rows
telecom.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %%
# to look the glimps of the data of bottom 5 rows
telecom.tail(5)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False

# %%
# shape of dataset with rows and column
print(telecom.shape)
# Out:
# (3333, 20)

# %%
#all the columns of dataset
print("Features of the data:")
telecom.columns
# Out:
# Features of the data:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ### **Features of column of the Data:**
#
# STATE: 51 Unique States name
#
# Account Length: Length of The Account
#
# Area Code: Code Number of Area having some States
#
# International Plan : Yes Indicate International Plan is Present and No Indicates no subscription for Internatinal Plan
#
# Voice Mail Plan: Yes Indicates Voice Mail Plan is Present and No Indicates no subscription for Voice Mail Plan
#
# Number vmail messages: Number of Voice Mail Messages ranging from 0 to 50
#
# Total day minutes: Total Number of Minutes Spent in Morning
#
# Total day calls: Total Number of Calls made in Morning.
#
# Total day charge: Total Charge to the Customers in Morning.
#
# Total eve minutes: Total Number of Minutes Spent in Evening
#
# Total eve calls: Total Number of Calls made in Evening.
#
# Total eve charge: Total Charge to the Customers in Evening.
#
# Total night minutes: Total Number of Minutes Spent in the Night.
#
# Total night calls: Total Number of Calls made in Night.
#
# Total night charge: Total Charge to the Customers in Night.
#
# Customer service calls: Number of customer service calls made by customer
#
# Churn: Customer Churn, True means churned customer, False means retained customer

# %%
#the data types of all the columns
telecom.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
#checking the details about the dataset
telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
#  14  Total night charge      3333 non-null   float64
#  15  Total intl minutes      3333 non-null   float64
#  16  Total intl calls        3333 non-null   int64
#  17  Total intl charge       3333 non-null   float64
#  18  Customer service calls  3333 non-null   int64
#  19  Churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 498.1+ KB

# %%
#Finding Null values present in data
telecom.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
#checking whether there is duplicates or not
len(telecom[telecom.duplicated()])
# Out:
# 0

# %% [markdown]
# **There is 3333 entries and no null values are present also there is no any duplicate value is present**

# %% [markdown]
# **Finding total number of churned users**

# %%
#Finding total number of churn users
telecom['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %% [markdown]
# **Out of the total 3333 customers, 2850 customers are retained and the rest 483 are churning the telecom service.**

# %%
#Finding the percentages of churn and plot the percentages in pie chart
Percent_churned_users = round((telecom['Churn'].mean() * 100),3)
Percent_unchurned_users = round((100 - Percent_churned_users),3)
x = [Percent_churned_users, Percent_unchurned_users]
labels = ['Churned users', 'Unchurned users']
explode = [0.1, 0]

fig, ax = plt.subplots(figsize=(4,3),dpi = 130)
ax.pie(x, labels = labels,explode = explode, autopct='%1.1f%%')
ax.set_title('Churn Analysis')
plt.show()

# %%
telecom
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [3333 rows x 20 columns]

# %%
#Visualize the charge distribution during day,evening & night
sns.set_color_codes()
sns.set_style("dark")
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
plt.title('Charges During Day')
sns.histplot(telecom['Total day charge'],color='g',bins=15)

plt.subplot(1,3,2)
plt.title('Charges During Evening')           
sns.histplot(telecom['Total eve charge'],color='g',bins=15)

plt.subplot(1,3,3)
plt.title('Charges During Night')
sns.histplot(telecom['Total night charge'],color='g',bins=15)
plt.show()

# %% [markdown]
# # **Conclusions:**
#
# From the table above, it can be seen that customers talk more during the day compared to the evening and night time.
#
# The average number of calls during the day, evening and night is almost the same.
#
# Apart from having a limited number of minutes to speak during the day, the costs incurred by the customer are higher compared to the evening and night talk minutes.
#
# It can also be visualized in the structure shown above.

# %%
# unique elements of the dataset
telecom.nunique()
# Out:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# Total night charge         933
# Total intl minutes         162
# Total intl calls            21
# Total intl charge          162
# Customer service calls      10
# Churn                        2
# dtype: int64

# %%
# Checking Duplicate Values
len(telecom[telecom.duplicated()])
# Out:
# 0

# %% [markdown]
# **As of now,
#  There are 3333 rows and 20 columns in above dataset.
# 1 boolean data type i.e churn
# 8 float data type,
# 8integer data type,
# 3 object data type i.e categorical value are there.
# There are no missing value present so no need to do the missing value imputation,
# And also there are no duplicate value present.**

# %%
#Printing the count of true and false in 'churn' feature#
print(telecom.Churn.value_counts())
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
#sorting the dataset
telecom.sort_values
# Out:
# <bound method DataFrame.sort_values of      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [3333 rows x 20 columns]>

# %%
#evaluating the mean of all entities
telecom['Churn'].mean()
# Out:
# 0.14491449144914492

# %%
#array of unique features of churns
print(telecom["Churn"].unique())
# Out:
# [False  True]

# %%
#the pie charts to analyze churn
sns.set(font_scale=1.25)
telecom['Churn'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%',  startangle=90,shadow='true',colors=['orange','red'], figsize=(8,8),fontsize = 15)
plt.title('Pie Chart for Churn',fontsize = 15)
plt.show()

# %%
#the Donut Plot to analyze churn
sns.set(font_scale=1.25)
data = telecom['Churn'].value_counts()
explode = (0, 0.2)
plt.pie(data, explode = explode,autopct='%1.1f%%',shadow=True,radius = 2.0,labels = ['Not churned customer','Churned customer'],colors=['yellow' ,'red'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.title('Donut plot for Churn',fontsize = 15)
plt.show()

# %%
from matplotlib.cbook import get_realpath_and_stat
# See churn by using countplot
sns.set(font_scale=1.25)
plt.figure(figsize = (5, 7))
graph=sns.countplot(x=telecom.Churn)
i=0
for p in graph.patches:
    height = p.get_height()
    graph.text(p.get_x()+p.get_width()/2., height + 0.1,
        telecom['Churn'].value_counts()[i],ha="center")
    i += 1
plt.title('Bar chart for Churn count')
# Out:
# Text(0.5, 1.0, 'Bar chart for Churn count')

# %% [markdown]
# ## **Above we get that 15% of customers have churned.**

# %%
#the unique value of state column
telecom['State'].nunique()
# Out:
# 51

# %%
#Showing the Comparison between churn and the state column
sns.set(style="whitegrid")
plt.figure(figsize=(15,8))
ax = sns.countplot(x='State', hue="Churn", data=telecom,palette=('muted'))
plt.title('Statewise churn analysis',fontsize = 20)
plt.show()

# %%
#statewise LIne graph
gt1=telecom['State'].unique()
gt2=telecom.groupby(['State'])['Churn'].mean()

plt.rcParams['figure.figsize'] = (18, 7)

plt.plot(gt1,gt2,color='g', marker='o', linewidth=2, markersize=12)

plt.title(" States churn rate", fontsize = 20)
plt.xlabel('state', fontsize = 15  )
plt.ylabel('churn rate', fontsize = 15)
plt.show()

# %%
#Statewise churn percentage
plt.rcParams['figure.figsize'] = (12, 7)
color = plt.cm.copper(np.linspace(0, 0.5, 20))
((telecom.groupby(['State'])['Churn'].mean())*100).sort_values(ascending = False).head(9).plot.bar(color = ['red','blue','pink','grey','y','orange','r','g','y'])
plt.title(" State with most churn percentage", fontsize = 20)
plt.xlabel('state', fontsize = 20)
plt.ylabel('percentage', fontsize = 20)
plt.show()

# %%
#churn vs state in percentage
State_data = pd.crosstab(telecom["State"],telecom["Churn"])
State_data['Percentage_Churn'] = State_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(State_data)
# Out:
# Churn  False  True  Percentage_Churn
# State
# AK        49     3          5.769231
# AL        72     8         10.000000
# AR        44    11         20.000000
# AZ        60     4          6.250000
# CA        25     9         26.470588
# CO        57     9         13.636364
# CT        62    12         16.216216
# DC        49     5          9.259259
# DE        52     9         14.754098
# FL        55     8         12.698413
# GA        46     8         14.814815
# HI        50     3          5.660377
# IA        41     3          6.818182
# ID        64     9         12.328767
# IL        53     5          8.620690
# IN        62     9         12.676056
# KS        57    13         18.571429
# KY        51     8         13.559322
# LA        47     4          7.843137
# MA        54    11         16.923077
# MD        53    17         24.285714
# ME        49    13         20.967742
# MI        57    16         21.917808
# MN        69    15         17.857143
# MO        56     7         11.111111
# MS        51    14         21.538462
# MT        54    14         20.588235
# NC        57    11         16.176471
# ND        56     6          9.677419
# NE        56     5          8.196721
# NH        47     9         16.071429
# NJ        50    18         26.470588
# NM        56     6          9.677419
# NV        52    14         21.212121
# NY        68    15         18.072289
# OH        68    10         12.820513
# OK        52     9         14.754098
# OR        67    11         14.102564
# PA        37     8         17.777778
# RI        59     6          9.230769
# SC        46    14         23.333333
# SD        52     8         13.333333
# TN        48     5          9.433962
# TX        54    18         25.000000
# UT        62    10         13.888889
# VA        72     5          6.493506
# VT        65     8         10.958904
# WA        52    14         21.212121
# WI        71     7          8.974359
# WV        96    10          9.433962
# WY        68     9         11.688312

# %%
# Arranging the above list in ascending order
#showing the most churn state of top 10 rows
telecom.groupby(['State'])['Churn'].mean().sort_values(ascending = False).head(10)
# Out:
# State
# NJ    0.264706
# CA    0.264706
# TX    0.250000
# MD    0.242857
# SC    0.233333
# MI    0.219178
# MS    0.215385
# NV    0.212121
# WA    0.212121
# ME    0.209677
# Name: Churn, dtype: float64

# %% [markdown]
# There are 51 unique state with different churn rate.
#
# these states ( CA, NJ, TX, MD, SC, MI) are those states which have higher rate of churned.

# %%
# Area code vs Churn in percent
Area_code_data = pd.crosstab(telecom["Area code"],telecom["Churn"])
Area_code_data['Percentage_Churn'] = Area_code_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(Area_code_data)
# Out:
# Churn      False  True  Percentage_Churn
# Area code
# 408          716   122         14.558473
# 415         1419   236         14.259819
# 510          715   125         14.880952

# %%
#Area Code vs churning rate
Area_code_data = pd.crosstab(telecom["Area code"],telecom["Churn"]).plot.bar()
plt.title('Area code wise churn analysis',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Area code wise churn analysis')

# %% [markdown]
# # **VOICE MAIL PLAN ANALYSIS**

# %%
# VOICE MAIL PLAN ANALYSIS:
voice_plan = telecom['Voice mail plan'].value_counts()
voice_plan
voice_plan.plot(kind = 'bar',color = ['r','g'])
plt.xlabel('Voice mail plan Status')
plt.ylabel('Number of users')
plt.title('voice mail plan analysis', fontsize=15)
plt.rcParams['figure.figsize'] = (5,5)

# %%
# INTERNATIONAL PLAN ANALYSIS:
international_voice_plan = telecom['International plan'].value_counts()
international_voice_plan
international_voice_plan.plot(kind = 'bar',color =['blue','green'])
plt.xlabel('International  plan Status')
plt.ylabel('Number of users')
plt.title('International plan analysis',fontsize = 15)
plt.rcParams['figure.figsize'] = (4,7)

# %% [markdown]
# # **from the above Data, we get there is no relationship between "area code" and "churn".**

# %%
#Separating churn and non churn customers
churn    = telecom[telecom["Churn"] == bool(True)]
not_churn = telecom[telecom["Churn"] == bool(False)]

# %%
#Account length vs Churn
sns.set_style("dark")
sns.distplot(telecom['Account length'],color='g')

# %%
# churned account length vs not churned account length 
sns.set_style("dark")
sns.distplot(telecom['Account length'],color = "green",label="All")
sns.distplot(churn['Account length'],color = "red",hist=False,label="Churned")
sns.distplot(not_churn['Account length'],color = "blue",hist= False,label="Not churned")
plt.legend()

# %% [markdown]
# # **from the above Data, we found there is not a great significance of "account length" on "churn"**

# %%
#counting the value of yes and no
telecom["International plan"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
#the unique data of "International plan"
telecom['International plan'].value_counts()
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %%
#the Donut Plot to analyze International Plan
sns.set(font_scale=1.25)
data = telecom['International plan'].value_counts()
explode = (0, 0.2)
plt.pie(data, explode = explode,autopct='%1.1f%%',shadow=True,radius = 2.0, labels = ['No','Yes'],colors=['orange' ,'skyblue'])
circle = plt.Circle( (0,0),1, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.title('Donut Plot for International plan')
plt.show()

# %%
#Countplot for international plan vs churn
sns.countplot(x='International plan',hue="Churn",data=telecom)
plt.title('International plan churn analysis',fontsize=15)
# Out:
# Text(0.5, 1.0, 'International plan churn analysis')

# %%
# Using groupby method to group international plan users and non-users and then further classifying on their churn status.
Intl_churn_rate = telecom.groupby(['International plan'])['Churn'].agg([np.mean]).rename(columns = {'mean':'churn_rate'})
churn_perct_with_no_Intl_plan = round((Intl_churn_rate.iloc[0,0]*100),3)
unchurn_perct_with_no_Intl_plan = 100 - churn_perct_with_no_Intl_plan
churn_perct_with_Intl_plan = round((Intl_churn_rate.iloc[1,0]*100),3)
unchurn_perct_with_Intl_plan = 100 - churn_perct_with_Intl_plan

# Getting a list of percentages with and without international plan on basis of churn status.
x1 = [churn_perct_with_no_Intl_plan, unchurn_perct_with_no_Intl_plan]
x2 = [churn_perct_with_Intl_plan, unchurn_perct_with_Intl_plan]

# Plotting a pie-chart
colors = sns.color_palette('bright')
labels = ['Churned users', 'Unchurned users']
explode = [0.05, 0]
fig = plt.figure(figsize=(6,7),dpi=144)
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax1.pie(x1,colors=colors, labels = labels,explode = explode, autopct='%1.2f%%', startangle=90 )
ax2.pie(x2, colors=colors,labels = labels,explode = explode, autopct='%1.2f%%', startangle=45 )
ax1.set_title('No International Plan')
ax2.set_title('International Plan')
plt.show()

# %% [markdown]
#  From the above data,
#
# 1-3010 customers- Dont have a international plan.
#
# 2-323 customers- have a international plan.
#
# 3-we conclude that 42.4% people churned among the international plan customers
#
# 4-11.4% people churned are among those who doesnt have the international plan
#
# we analyse that those who have international plan have high chance to be a churned customer may be due to connectivity issue or high charges.

# %%
#the data of 'Number vmail messages'
telecom['Number vmail messages'].unique()
# Out:
# array([25, 26,  0, 24, 37, 27, 33, 39, 30, 41, 28, 34, 46, 29, 35, 21, 32,
#        42, 36, 22, 23, 43, 31, 38, 40, 48, 18, 17, 45, 16, 20, 14, 19, 51,
#        15, 11, 12, 47,  8, 44, 49,  4, 10, 13, 50,  9])

# %%
#counting the value of the data of 'Number vmail messages'
telecom['Number vmail messages'].value_counts()
# Out:
# 0     2411
# 31      60
# 29      53
# 28      51
# 33      46
# 27      44
# 30      44
# 24      42
# 26      41
# 32      41
# 25      37
# 23      36
# 36      34
# 22      32
# 35      32
# 39      30
# 34      29
# 37      29
# 21      28
# 38      25
# 20      22
# 19      19
# 40      16
# 42      15
# 17      14
# 16      13
# 41      13
# 43       9
# 15       9
# 18       7
# 44       7
# 14       7
# 45       6
# 12       6
# 46       4
# 13       4
# 47       3
# 50       2
# 9        2
# 8        2
# 11       2
# 48       2
# 49       1
# 4        1
# 10       1
# 51       1
# Name: Number vmail messages, dtype: int64

# %%
#describing the 'Number vmail messages'
telecom['Number vmail messages'].describe()
# Out:
# count    3333.000000
# mean        8.099010
# std        13.688365
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        20.000000
# max        51.000000
# Name: Number vmail messages, dtype: float64

# %%
#histogram diagram
fig = plt.figure(figsize =(10, 10)) 
sns.histplot(telecom['Number vmail messages'])
plt.title('Histogram for no of voicemail messages')
# Out:
# Text(0.5, 1.0, 'Histogram for no of voicemail messages')

# %%
#boxplot diagram between 'number vmail messages' and 'churn'
fig = plt.figure(figsize =(20, 10)) 
telecom.boxplot(column='Number vmail messages', by='Churn')
plt.xlabel('churn')
plt.ylabel('no of vmail messages')
plt.show()

# %% [markdown]
# **From the above data, we found that when there are more than 20 voice-mail messages then there is a churn.
# To solve this issue we have to improve the call quality.**

# %%
#the unique value of the "Voice mail plan" column
telecom["Voice mail plan"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
#the Voice Mail Plan vs Churn percentage
Voice_mail_plan_data = pd.crosstab(telecom["Voice mail plan"],telecom["Churn"])
Voice_mail_plan_data['Percentage Churn'] = Voice_mail_plan_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(Voice_mail_plan_data)
# Out:
# Churn            False  True  Percentage Churn
# Voice mail plan
# No                2008   403         16.715056
# Yes                842    80          8.676790

# %%
#the Donut Plot to analyze Voice mail plan
data = telecom['Voice mail plan'].value_counts()
explode = (0, 0.2)
plt.pie(data, explode = explode,autopct='%1.1f%%',startangle=90,shadow=True,radius = 2.0, labels = ['NO','YES'],colors=['skyblue','orange'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.title('Donut Plot for Voice mail plan')
plt.show()

# %%
#Splitting the dataset between churned customers and non-churned customers
telecom_churned = telecom[telecom['Churn'] == True]
telecom_unchurned = telecom[telecom['Churn'] == False]

# Adding column 'Months' to classify data into months
telecom_churned = telecom_churned.assign(Months = lambda x: (x['Account length'] //28))
telecom_unchurned = telecom_unchurned.assign(Months = lambda x: (x['Account length'] //28))

# Doing monthly analysis for both datasets
monthly_analysis_churned = telecom_churned.groupby('Months')['Months'].describe()
monthly_analysis_unchurned = telecom_unchurned.groupby('Months')['Months'].describe()

# Distribution of customers churned out over months
monthly_analysis_churned.reset_index(inplace=True)
plt.rcParams['figure.figsize'] = (10, 6)
monthly_analysis_churned = monthly_analysis_churned.assign(Churned_customers_percentage = lambda x: (x['count'] /sum(monthly_analysis_churned['count']) * 100))
list_of_percentages = list(monthly_analysis_churned['Churned_customers_percentage'].values)

# Adding new labels to show percentage
zipped_dict = dict(zip([0,1,2,3,4,5,6,7,8],list_of_percentages))
new_labels = []
for data in zipped_dict.items():
  new_labels.append(str(data[0]) + ' : ' + str(round(data[1])) + '%')
labels=new_labels
myexplode = [0,0,0.05,0.05,0.05,0,0,0,0]
plt.pie(list_of_percentages,explode=myexplode,startangle = 90)
plt.legend(labels, title='Months', bbox_to_anchor = (1.05, 0.8))
plt.title('Churned Customer Percentage Across Months',fontsize=15)
plt.show()

# %%
#Analysing by using countplot
sns.countplot(x='Voice mail plan',hue="Churn",data = telecom)

# %% [markdown]
# ###There is no significance of voice mail plan on churn. so, lets see other significant factors on which churn is depend.

# %%
#Customer service call analysis
telecom['Customer service calls'].value_counts()
# Out:
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: Customer service calls, dtype: int64

# %%
#Customer service call vs churn analysis
Customer_service_calls_data = pd.crosstab(telecom['Customer service calls'],telecom["Churn"])
Customer_service_calls_data['Percentage_Churn'] = Customer_service_calls_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(Customer_service_calls_data)
# Out:
# Churn                   False  True  Percentage_Churn
# Customer service calls
# 0                         605    92         13.199426
# 1                        1059   122         10.330229
# 2                         672    87         11.462451
# 3                         385    44         10.256410
# 4                          90    76         45.783133
# 5                          26    40         60.606061
# 6                           8    14         63.636364
# 7                           4     5         55.555556
# 8                           1     1         50.000000
# 9                           0     2        100.000000

# %%
##Customer service call vs churn graph analysis
sns.countplot(x='Customer service calls',hue="Churn",data = telecom)

# %%
print(telecom.groupby(["Churn"])['Total day calls'].mean())
# Out:
# Churn
# False    100.283158
# True     101.335404
# Name: Total day calls, dtype: float64

# %%
print(telecom.groupby(["Churn"])['Total day minutes'].mean())
# Out:
# Churn
# False    175.175754
# True     206.914079
# Name: Total day minutes, dtype: float64

# %%
print(telecom.groupby(["Churn"])['Total day charge'].mean())
# Out:
# Churn
# False    29.780421
# True     35.175921
# Name: Total day charge, dtype: float64

# %%
#Total day charges vs churn analysis
sns.scatterplot(x="Total day minutes", y="Total day charge", hue="Churn", data=telecom)
